# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %%
#Membaca semua data kemudian menggabungkannya menjadi satu
df = pd.DataFrame(columns=['Package Name', 'App Version Code', 'App Version Name',
       'Reviewer Language', 'Device', 'Review Submit Date and Time',
       'Review Submit Millis Since Epoch', 'Review Last Update Date and Time',
       'Review Last Update Millis Since Epoch', 'Star Rating', 'Review Title',
       'Review Text', 'Developer Reply Date and Time',
       'Developer Reply Millis Since Epoch', 'Developer Reply Text',
       'Review Link'])
files = glob.glob(r'*.csv')
for f in files:
    Data = pd.read_csv(f,sep=',',encoding="utf-16")
    df = pd.concat([Data,df])
    print(df.shape)

df.head()
# Out:
# (9, 16)
# (22, 16)
# (72, 16)
# (98, 16)
# (122, 16)
# (125, 16)
# (167, 16)
# (178, 16)
# (185, 16)
# (192, 16)
# (195, 16)
# (200, 16)
# (201, 16)
# (214, 16)
# (215, 16)
# (248, 16)
# (250, 16)
#          Package Name  ...                                        Review Link
# 0  com.pos.bisatampil  ...  http://play.google.com/console/developers/5503...
# 1  com.pos.bisatampil  ...  http://play.google.com/console/developers/5503...
# 0  com.pos.bisatampil  ...  http://play.google.com/console/developers/5503...
# 1  com.pos.bisatampil  ...  http://play.google.com/console/developers/5503...
# 2  com.pos.bisatampil  ...  http://play.google.com/console/developers/5503...
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 8
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Package Name                           250 non-null    object
#  1   App Version Code                       184 non-null    float64
#  2   App Version Name                       184 non-null    object
#  3   Reviewer Language                      250 non-null    object
#  4   Device                                 247 non-null    object
#  5   Review Submit Date and Time            250 non-null    object
#  6   Review Submit Millis Since Epoch       250 non-null    object
#  7   Review Last Update Date and Time       250 non-null    object
#  8   Review Last Update Millis Since Epoch  250 non-null    object
#  9   Star Rating                            250 non-null    object
#  10  Review Title                           0 non-null      float64
#  11  Review Text                            187 non-null    object
#  12  Developer Reply Date and Time          82 non-null     object
#  13  Developer Reply Millis Since Epoch     82 non-null     float64
#  14  Developer Reply Text                   82 non-null     object
#  15  Review Link                            187 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 33.2+ KB

# %%
# Membuat new_df dari df
new_df = df[['Star Rating','Review Text']]
new_df.head()
# Out:
#   Star Rating                                        Review Text
# 0           1  Payah.. seharian ini saya gak bisa buka aplika...
# 1           1  Hati hati aplikasi penipuan sertifikat 1 mingg...
# 0           5  Aplikasi yang memudahkan kita untuk melakukan ...
# 1           5  Sangat membantu di kondisi wfh seperti sekaran...
# 2           5  Conference call, video chat, share screen muda...

# %%
#Menambahkan kolom sentiment
sentiment = []
for _, row in new_df.iterrows():
  if row['Star Rating'] >= 4:
    sentiment.append('Positif')
  elif row['Star Rating'] == 3:
    sentiment.append('Netral')
  else:
    sentiment.append('Negatif')

new_df['Sentiment'] = sentiment
new_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#   Star Rating                                        Review Text Sentiment
# 0           1  Payah.. seharian ini saya gak bisa buka aplika...   Negatif
# 1           1  Hati hati aplikasi penipuan sertifikat 1 mingg...   Negatif
# 0           5  Aplikasi yang memudahkan kita untuk melakukan ...   Positif
# 1           5  Sangat membantu di kondisi wfh seperti sekaran...   Positif
# 2           5  Conference call, video chat, share screen muda...   Positif

# %%
#Cek data yang kosong
new_df.isna().sum()
# Out:
# Star Rating     0
# Review Text    63
# Sentiment       0
# dtype: int64

# %%
#mengganti comment kosong yg positif menjadi bagus
new_df['Review Text'] = np.where((new_df['Review Text'].isna() & new_df.Sentiment.str.contains('Positif')),'bagus',new_df['Review Text'])
new_df['Review Text'] = np.where((new_df['Review Text'].isnull() & new_df.Sentiment.str.contains('Positif')),'bagus',new_df['Review Text'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_df.isna().sum()
# Out:
# Star Rating    0
# Review Text    2
# Sentiment      0
# dtype: int64

# %%
new_df['Review Text'].fillna('NaN', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
new_df.isna().sum()
# Out:
# Star Rating    0
# Review Text    0
# Sentiment      0
# dtype: int64

# %%
#Melihat Persebaran Datanya
new_df.groupby(['Sentiment','Star Rating'])['Review Text'].count()
# Out:
# Sentiment  Star Rating
# Negatif    1               25
#            2                7
# Netral     3                6
# Positif    4               11
#            5              201
# Name: Review Text, dtype: int64

# %%
print(new_df['Review Text'].values)
# Out:
# ['Payah.. seharian ini saya gak bisa buka aplikasinya.'
#  'Hati hati aplikasi penipuan sertifikat 1 minggu udah gk kluar dan juga aplikasi gk bisa di buka'
#  'Aplikasi yang memudahkan kita untuk melakukan meeting secara online dimanapun dan kapanpun dengan fitur yang sangat lengkap'
#  'Sangat membantu di kondisi wfh seperti sekarang ini'
#  'Conference call, video chat, share screen mudah. Gratis jg. Kalau mau yg pro harga nya terjangkau dan bisa bayar transfer.. bisa join room dan lihat event yg available. Bagus banget apps nya'
#  'Bermanfaat untuk apps tellhealth. Terima kasih BISA Tampil'
#  'Keren sekali aplikasinya bisa d pakai untuk rapat tanpa lambat dan batas jam. Bisa pakai up to 5 jam non stop'
#  'Aplikasinya sangat bagus cocok nih untuk dipakai meeting online di tunggu untuk versi selanjutnya :)'
#  'Mantap. BISA Tampil menjadi solusi bagi kami mahasiswa yg sedang melaksanakan perkuliahan... Terima kasih'
#  'Tampilan yang simpel, fiturnya lengkap, terutama share screen yg bisa dipakai buat belajar, meeting dan keperluan lain😁'
#  'Aplikasinya sangat membantu untuk meeting/kuliah online dan tampilannya sangat mudah dipahami. Tingkatkan lagi'
#  'Bisa banget buat dipakai meeting online atau untuk video call group. Fiturnya lengkap, simple, dan mudah digunakan.'
#  'Aplikasi ini sangat bagus. Bantu saya dalam meeting online. Fiturnya sangat lengkap dan mudah dioperasikan. Recommended banget buat kalian, apalagi kalau urusan harga.'
#  'Aplikasi yang bagus, desainnya simpel, mudah digunakan, dan fitur2nya menarik. Sangat ditunggu update selanjutnya'
#  'Keren, fiturnya lengkap, dan mudah digunakan. Cocok buat meeting online dengan banyak peserta.'
#  'Cocok banget nih buat meeting online. Fiturnya lengkap dan mudah digunakan'
#  'bagus' 'cool apps!'
#  'Tampilan bagus dan mudah untuk dipahami. Fitur lengkap, sangat direkomendasikan untuk digunakan apalagi diera pandemi seperti sekarang. Aplikasi yang sangat user friendly.'
#  'Membantu sekali dalam kegiatan yang memerlukan tatap muka jarak jauh'
#  'bagus'
#  'Tampilan aplikasi user friendly, paket terjangkau. Sangat berguna saat wfh seperto sekarang'
#  'Aksesnya sangat mudah' 'bagus' 'bagus' 'Nice' 'bagus'
#  'Sangat Berguna sekali , untuk video conference, ataupun silaturahmi dengan teman teman secara online'
#  'bagus' 'Masih ada bug' 'I love this app' 'Keren cuy' 'bagus'
#  'Kenapa harus pake akun dulu? Padahal di app meeting lain ga harus. Itupun proses pendaftaran akunnya ga bisa. Sudah berkali kali cek email ga ada email verifikasi. Pas dicoba login, gabisa.'
#  'bagus' 'bagus' 'Mantap'
#  'Nggak bisa full screen di app. Apa cuma hpku doang?' 'Great! Useful app'
#  'bagus' 'bagus' 'Fitur yang kurang itu integrasi dengan kalender'
#  'Error pengambilan gambar untuk upload foto profil' 'Amazing'
#  'Kasih bintang segini dulu, karena ada bug yang ditemukan ketika daftar dan mau menambahkan photo profil aplikasi sering force close sehingga proses pendaftaran tidak bisa dilakukan. Jadi kayak percuma install appsnya kalo gabisa terpakai karena gabisa upload profile mohon diperbaiki'
#  'bagus' 'bagus' 'manteps' 'Ini sangatlah mantab'
#  'forced stop terus sejak update' 'bagus' 'Bagus'
#  'Di perangkat saya ga ada suaranya, kenapa ya? Download sertifikat juga ga bisa2. Mau lapor problem ternyata ga ada di menu aplikasi jadinya lapor sini aja'
#  'bagus' 'NaN' 'bagus' 'Mantul' 'bagus'
#  'Tampil merupakan salah satu video conference yang sudah terbilang bagus dan dapat bersaing dengan aplikasi sejenis lainnya. Dan sudah jelas tampil ini adalah aplikasi video conference asli Indonesia yang dibuat oleh Bisa AI. Selain sebagai platform video conference tampil juga menyediakan berbagai event seperti webinar yang dapat meningkatkan skill kita dan sudah mendapatkan e-certificate juga. Pokoknya tampil mantap dan sangat membanggakan bagi negara Indonesia'
#  'Aplikasinya sangat berguna untuk menambah ilmu dan topik webinarnya sangat menarik. Terima kasih Bisa Ai'
#  'Aplikasi yang bagus untuk mendapatkan ilmu dari workshop dan webinar webinar yang isinya daging banget huhu'
#  'Sesuai namanya aplikasi TAMPIL menampilkan segala bentuk hal dari webinar hingga event yang sangat bermanfaat untuk menambah wawasan materi melalui online dan ada juga merchandise yang bisa didapatkan oleh teman teman yang download aplikasi TAMPIL.'
#  'Aplikasinya bagus, terutama buat para pencari event atau penyelenggara event, karena dapat digunakan untuk konferensi, event, ataupun webinar yang dilengkapi share screen, polling, dsb. Tentunya setelah acara busa mendownload sertifikat acaranya.'
#  'Aplikasi TAMPIL ini sangat mudah digunakan bagi pemula, dan cocok sekali bagi orang yang nyaman dan ingin belajar Artificial Intelligence melalu event atau webinar🤗. Dalam satu aplikasi, kita sudah dapat mendapatkan info lengkap mengenai event atau webinar, jadi terpusat banget sumbernya. Ada sertifikatnya juga! Pokoknya keren!🤗'
#  'Aplikasi bermanfaat terutama buat pencari event ataupun penyelenggara event'
#  'Flatfoam VC nya mantap, awet kuota dan mudah diaplikasikan' 'bagus'
#  'bagus' 'bagus'
#  'Aplikasinya tambah di update ko tambah lemot Pas mau ikut seminar jaringannya langsung down'
#  'Webinarnyaa seru' 'bagus' 'bagus' 'bagus'
#  'Saya pakai android 11, kenapa tidak bisa d buka yaa? Klik aplikasi lgsg close'
#  'Aplikasi tidak bisa terbuka di android 11...' 'bagus' 'NaN'
#  'Kenapa mau buka apk nya langsung keluar ?'
#  'Sertifikatnya terlalu lama. Udah seminggu setelah ikut event tapi sertifikatnya belum turun turun.'
#  'bagus' 'App nya kerennn' "Application can't open"
#  "very useful and easy to use conference apps. hope there'll having a new great feature nextime! 🧡"
#  'Love it!' 'keren banget' 'Baguss Up to date banget👍🏻'
#  'Aplikasinya keren & sangat bermanfaat'
#  'Local masterpiece. You can find great speakers and learn about AI from them'
#  'Keren banget aplikasinya'
#  'setelah diinstall aplikasi nya error namun setelah itu berjalan dengan baik'
#  'Such a helpful and useful app.' 'Keren, semoga semakin baik!'
#  'Aplikasi keren banget, ini berguna banget apalagi diera pandemi gini. Ini nih yang dicari2. 100% recommended'
#  'Semangat terus mengembangkan produk lokal! Bangga'
#  'Aplikasinya bagus, sangat informatif. Apalagi disaat pandemi gini semua serba online jadi aplikasi ini sangat recomended banget'
#  'Very useful and such a great app for learning👍' 'Menarik dan bagus'
#  'Aplikasi cukup ngebantu ketika kita butuh ikut kegiatan webinar, informasi yg disediakan sangat lengkap dan memudahkan.'
#  'Very easy to use and useful'
#  'Aplikasi yang sangat berguna dalam mencari webinar terkait AI'
#  'Useful app'
#  'Aplikasinya bagus sekali, memuat beragam info tentang webinar2. Sehingga kita bisa mengikuti webinar2 di tengah pandemi ini. Sangar recomend sekali bagi orang orang yang aktif dan ingin mencari banyak ilmu'
#  'Aplikasinya bagus, layanan yang disediakan juga bermanfaat dan menarik banget'
#  'Aplikasi tidak bisa dipakai (force closed) setiap dibuka' '👍👍'
#  'Very usefull this apps'
#  'Aplikasi yang sangat membantu bagi kita yang mau tetap produktif di masa oandemi seperti ini. Tampil memiliki banyak keunggulan seperti webinad gratis SETIAP HARI, sertifikat digital dan bisa diskusi langsung dengab narasumber. sangat direkomendasikan aplikasi TAMPIL 😊😊'
#  'Sangat membantu sebagai platform komunikasi digital tatap muka 🙏'
#  'sangat baik dan semoga bisa bersaing dan dikenal masyarakat luas.'
#  'Terima kasih, sudah jadi aplikasi webinar dan pembelajaran yang keren. Saya banyak belajar.'
#  'Salah satu platform lokal untuk video conference, semoga semakin menjadi terbaik kedepannya0'
#  'Bagus banget, membantu buat cari" webinar gratis'
#  'Setiap Event atau Webinar yang disediakan sangat menarik untuk diikuti. Semoga performa TAMPIL kedepannya semakin baik.'
#  'Keren sihh bisa belajar melalui webinar jd cocok bgt buat yg lg wfh dan pematerinya hebatt dibidangnya'
#  'Sangat membantu untuk produktif di kondisi pandemi ini'
#  'Aplikasinya bagus, sangat cocok digunakan dimasa pandemi seperti ini . Sangat membantu dan mudah untuk mengaplikasikan'
#  'Tampil sangat baik dalam menyelenggarakan event-event yang sulit untuk dicari terutama pada masa pandemi ini. Webinar-webinar yang diadakan sangat bermanfaat dan juga memberikan banyak benefit bagi mereka yang mengikutinya seperti sertifikat dan juga hadiah.'
#  'Keren bgt' 'Sangat bermanfaat'
#  'Bagus banget aplikasinya, apalagi kalo webinar bener bener sangat mendukung apk tampil ini'
#  'Great app !'
#  'Everytime i open this app, it always forces stop automatically, i dunno why. But by seeing the app summary, i think this app really useful for making an event webinar.'
#  'Tap mantap' 'Aplikasi yang dapat menambah pengalaman' 'bagus' 'bagus'
#  'full-screen nya gk bisa :(' 'bagus'
#  'Sudah hadir event dari awal hingga akhir..., tapi tidak di sertifikatnya tercatat! Sampai saya harus melalui link. LEBIH BAGUS LINKNYA DARIPADA APLIKASINYA!!!'
#  'Koneksi Lambat server lambat, tampilan Ui video conference mirip sama yang udah ada pasti Vendor 1 orang dan bagian UI nya ga mau repot ubah'
#  'Gaada suara nya , udh diklik join audio ttp gaada'
#  'Tampilan UI sangat baik dan kekinian, akses aplikasi cukup ringan, UX sangat baik, terus pertahankan, semoga bisa Ai kedepan semakin maju dan sukses, dan terus lah menyebar ilmu yang bermanfaat dibidang AI buat masyarakat luas, terima kasih'
#  'Platform video conference yang bagus dan banyak event event yang menarik tentang data science dan AI serta event menarik lainnya, tidak rugi install aplikasi ini sangat bermanfaat, good job bisa ai'
#  'bagus' 'bagus' 'bagus' 'Udah ikut seminar , e-sertifikat nya kaga dapat'
#  'bagus' 'bagus' 'ManTulPis 🌟🌟🌟🌟🌟' 'bagus'
#  'Pas udh diupdate malah keluar trus dia' 'Well'
#  'Semoga dapat E-sertifikat gratis 🤭'
#  'Bagusan di web nya. Juga sertifikat nya lama bgt. Di percepat sebaiknya 2-3 hari saja'
#  'bagus' 'bagus' 'bagus' 'bagus' 'bagus' 'bagus'
#  'Apk tipu² sertifikat nya juga ga muncul² walau udah bayar' 'bagus'
#  'Really helpfull' 'bagus' 'Useful app.' 'Oke' 'bagus' 'bagus' 'bagus'
#  'Aplikasi berfungsi dengan baik'
#  'Sedih banget baru update udah ga bisa di buka lagi force closed terus :( , team dev mban atuh mau ikutan belajar kita udh enroll...'
#  'Mantap' 'Sangat ringan'
#  'One of the best meeting video conference,i appreciate that'
#  'Begitu di instal udah masukin email dan password gk bisa kbuka² malah kembali lagi. Udah gitu di web nya gk ada sertifikat langsung harus konfirmasi dulu ke alamat emailnya...'
#  'bagus' 'Produk asli lokal, full support!' 'bagus' 'bagus' 'bagus'
#  'Can\'t stay logged in, multiple "wrong email/password" warning even though I put the correct login info, saved events disappearing from my event page, can\'t delete my account.'
#  'Mantap' 'Mantap'
#  'Aplikasinya di akhir2 segmen suka error kalo udah keluar, gak bisa masuk webinarnya lagi dan e-sertifikat juga gak ada padahal udah berhari2 webinar selesai. Appnya tiba2 log out sendiri terus password dianggap salah terus padahal udh benar. Coba klik reset password katanya konfirmasinya dikirim via email tp udah lewat sehari gak ada email masuk dr aplikasi tampil ini.. Jd harus buat akun baru lg dengan email baru.. Sy sudah hubungi kalian sesuai ketentuan yaitu via whatsApp tp gak ada respon.'
#  'Aplikasinya bagus, sedikit tambahan Kak untuk masukkan, penggunaan keyboard untuk public chat seringkali gagal berfungsi, sehingga kita sering terganggu saat akan menuliskan pertanyaan serta jawaban. Selain itu masukan juga Kak untuk penggunaan keyboard pada public chat, sebaiknya preview textnya diperlihatkan diatas supaya kelihatan, karena pas ngetik Text preview tertutup keyboard. Terimakasih.'
#  'bagus'
#  'Tidak bisa dibuka sama sekali, selalu berhenti ketika dibuka, tidak pernah berhasil membuka aplikasi'
#  'bagus' 'bagus'
#  'Dengan aplikasi Tampil, saya bisa lebih update tentang informasi Webinar yang bermanfaat untuk menambah pengetahuan dan mengembangkan skill saya'
#  'Sangat baik sekali untuk webinar'
#  'Aplikasi ini sangat membantu bagi mahasiswa yang sedang mencari webinar secara daring karena Pandemi. Webinar tersebut sudah dibuat timeline dari tanggal 21 Agustus hingga beberapa event lainnya. So, jangan takut untuk mencoba'
#  'Aku suka sama aplikasi nya tinggal di tingkatkan kembali'
#  'Yang ga ada di zoom adalah webinar gratis buat nambah wawasan. Support produk lokal!'
#  'tenkyuu banget jadi ada kegiatan pas ppkm kek gini'
#  'Sangat membantu saya dalam menemukan webinar yang nantinya dapat bermanfaat untuk memperkaya pengetahuan saya.'
#  'Bagus banget apknya bisa dapet informsi webinar banyak' 'bagus'
#  'Ini aplikasi yg sangat bermanfaat karena berisi event-event menarik untuk belajar IT dan event gratisnya sangat worth it'
#  'Aplikasi tampil ini sangat bermanfaat. Memudahkan kita dalam mencari dan mendaftar webinar serta event yang setiap harinya ada. Kita juga bisa diskusi langsung dengan narasumber. Tentunya kita mendapatkan sertifikat apabila mengikuti event/webinar dari aplikasi tampil. Aplikasi ini dilengkapi dengan layanan forum dan berita. Banyak bgt benefit yg didapatkan😍'
#  'Aplikasi yang rekomended nih bisa dicoba untuk meeting apapun. Terimakasih telah membuat pilihan aplikasi agar tidak jenuh😻'
#  'Apliksi TAMPIL menampilkan, menyelenggarakan event, webinar, dan pembelajaran menggunakan video conference yang dapat digunakan melalui web, android, dan iOS. Tampil membuka kesempatan anda untuk tampil dan berkolaborasi. Kita dapat bergabung di room yang telah di informasikan, tampil juga mempunyai parter rutin. Menurut saya aplikasi ini sangat membantu di masa pandemi.'
#  'Appnya useful dan bagus 👍'
#  'Aplikasi nya kenapa tiba2 susah dibuka sih, tolong diperbaiki lagi terimakasih'
#  'Aplikasi yg menyediakan info lengkaprksiy webinar dan event!! Terutama yang relate dengan AI dan tech. Bener bener rekomended dan hrus di donlot'
#  'keren'
#  'Aplikasi ini sangat membantu saya dalam mengetahui kegiatan diluar seperti seminar, tidak hanya itu dengan aplikasi ini kita bisa ikut seminar dan kegiatan lainnya.'
#  'KERENN BANGETTTT APLIKASI TERBAIK DI PLAYSTORE MANTAP'
#  'This is insighful aplication to looking for webinar and another activities that can create better education'
#  'Very good apps to hold a educational webinar, conference, and workshop'
#  'Sebagai dat enthusiast dan mahasiswa, dimasa pandemi seperti sekarang ini sangat terbantu dengan aplikasi ini. Banyak workshop, dan event pelatihan² webinar yang rutin diadakan khusus terkait AI, ML dan teknologi lainnya. Dapet sertifikat juga. Fiturnya berupa video conference sangat efektif dan mudah digunakan.'
#  'aplikasinya bagusssdd'
#  'Aplikasi tampil sangat berguna untuk menampilkan, menyelenggarakan event, webinar dan pembelajaran menggunakan video conference. Berbagai fitur yang ditampilkan membuat kita lebih mudah untuk mengoperasikannya. Kita dapat bergabung di room yang telah diinformasikan, tampil juga mempunyai parter rutin'
#  'Aplikasi tampil ini sangat membantu kita untuk mencari info tentang webinar selain itu kita juga dapat mendaftar diaplikasi secara langsung dan berhubungan langsung dengan narasumber dan tak lupa juga dapet sertifikat loh 😎'
#  'Easy to use, great performance 👏'
#  'Sangat bermanfaat dan memudahkan mahasiswa yang berkeinginan untuk mengembangkan diri dengan mengikuti berbagai conference'
#  'Aplikasi ini ringan dalam penggunaan dan fiturnya recomended banget'
#  'bagus'
#  'Bermanfaat sekali bagi pelajar atau umum yang cari event, webinar dll di masa sekarang yang harus melalui virtual'
#  'Aplikasi yang menyelenggarakan berbagai macam webinar,event, bahkan conference yang mudah sekali untuk di gunakan. Sangat rekomendasi buat teman-teman yang mungkin sedang mencari webinar atau event untuk menambah wawasan.'
#  'Saya sebagai mahasiswa aplikasi ini bagus dan sangat membantu untuk menambah ilmu melalui webinar'
#  'Aplikasi tampil mengadakan event, webinar, dan bisa diakses dari IOS dan Android, dan sangat banyak benefit yang kita dapat dari aplikasi ini'
#  'Udah instal tapi ga mau dibuka. Ga nyampe sedetik nutup sendiri. Huhuuu'
#  'Informatif mantap sekali'
#  'Aplikasi yang sangat bermanfaat, di dalamnya memuat berbagai event, sehingga mempermudah mahasiswa yang ingin mencari event seperti webinar, dll.'
#  'aplikasi yg bermanfaat bagi kita yg aktif webinar dan mencari event, dipermudah dengan app ini'
#  'this app suitable for whose seeking webinar and event, this app is useful for me'
#  'Bagus'
#  'Aplikasi inovatif, semoga terus berkembang lebih baik lagi dan menjadi kontributor Indonesia Maju.'
#  'Aplikasinya aangat membantu mahasiswa dalam mencari webinar'
#  'Aplikasi yang sangat bermanfaat, banyak informasi mengenai webinar maupun event secara gratis. Kita juga bisa dapat sertifikat kalo ikutan webinarnya. Sangat membantu untuk mengisi waktu luang apalagi dimasa pandemi seperti ini.'
#  'very useful'
#  'Keren, seru-seru webinarnya🤙 Ditunggu selalu webinar keren selain react js kemarin wiw💫'
#  'Aplikasinya sangat bermanfaat dalam mencari webinar👍'
#  'mungkin bisa di perluas fitur webinar dalam aplikasinya biar mudah dalam penggunaan.'
#  'Aplikasi ini sangat berguna dan bermanfaat untuk membuat sebuah webinar. Aplikasi ini banyak membantu berbagai kemudahan untuk menyelenggarakan webinar.'
#  'Keren untuk video conference 👍👍👍' 'Webinar lancarr 😍'
#  'Aplikasi yang bagus 👍 karena baru ada platform aplikasi yang isinya webinar dan sekaligus vidconf di aplikasi tsb, jadi kesannya sangat memuaskan 👍'
#  'bagus' 'bagus'
#  'Aplikasi karya anak bangsa yg dibuat khusus untuk webinar free dan berbayar yang terhubung langsung dgn pemateri yg sdh dijadwalkan di aplikasi Bisa.AI Academy. Recommended bgt. 👍'
#  'Aplikasi ga bener ajg ,baru download masa ga bisa dibuka kluar" sndiri Bkin emosi ae ni aplikasi'
#  'Pengalaman yang menyenangkan'
#  'Tampilan dan pilihan webinarnya banyak, keren banget!' 'bagus' 'bagus'
#  'Aplikasi berhenti sendiri saat akan daftar melalui gmail, dan tidak sampai 3menit setelah download aplikasi tidak bisa dibuka'
#  'luar biasa' 'Keren banget' 'bagus'
#  'Keren banget aplikasi nya. Bisa ikut berbagai kegiatan dan event'
#  'bagus'
#  'Keren banget ini aplikasi bisa membantu banget buat pembelajaran online👍'
#  'bagus' 'Mantap dah'
#  'Menginspirasi Tempat nya belajar Informatika, keren banget.. Mohon di pertahankan dan Mudah2han Bisa ai Tampil makin besar Aminn'
#  'Crash app']

# %%
#Lihat persebaran kata di review text yang positif
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Positif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Lihat persebaran kata di review text yang netral
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Netral')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Lihat persebaran kata di review text yang negatif
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Negatif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %% [markdown]
# # Preprocessing Text

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 5.1 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
#Pre Process Text untuk menghilangkan stop word
from nltk.tokenize import sent_tokenize, word_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
import re
import string

def pre_process(text):
    # Case Folding: Lowercase
    # Merubah format teks menjadi format huruf kecil semua (lowercase).
    text = text.lower()

    # Case Folding: Removing Number
    # Menghapus karakter angka.
    text = re.sub(r"\d+", "", text)
    # Menghapus kata yg kurang dari 4 huruf
    text = re.sub(r'\b\w{1,3}\b', '', text)

    # Case Folding: Removing Punctuation
    # Menghapus karakter tanda baca.
    text = text.translate(str.maketrans("","",string.punctuation))

    #Case Folding: Removing Whitespace
    #Menghapus karakter kosong.
    text = text.strip()

    #Menghapus emote icon
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    text = emoji_pattern.sub(r'', text) # no emoji
    
    #Separating Sentences with Split () Method
    #Fungsi split() memisahkan string ke dalam list dengan spasi sebagai pemisah jika tidak ditentukan pemisahnya.
    pisah = text.split()
    # atau dengan re.split(r'\s+',text)

    #Filtering using sastrawi
    # Ambil Stopword bawaan
    stop_factory = StopWordRemoverFactory().get_stop_words()
    more_stopword = ['dengan', 'ia','bahwa','oleh','ngga','jadi','doang','yg','tdk', 'yang', 'dan', 'juga']
    # Merge stopword
    data = stop_factory + more_stopword
    # Menfilter stopword dengan tambahan stopword baru
    dictionary = ArrayDictionary(data)
    stopword = StopWordRemover(dictionary)
    text =  stopword.remove(text)

    return text

new_df['Review Text'] = new_df['Review Text'].apply(lambda x:pre_process(x))
new_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Star Rating                                        Review Text Sentiment
# 0           1                  payah seharian   buka aplikasinya   Negatif
# 1           1  hati hati aplikasi penipuan sertifikat  minggu...   Negatif
# 0           5  aplikasi memudahkan untuk melakukan meeting on...   Positif
# 1           5                 sangat membantu  kondisi  sekarang   Positif
# 2           5  conference call video chat share screen mudah ...   Positif

# %%
print(new_df['Review Text'].values)
# Out:
# ['payah seharian   buka aplikasinya'
#  'hati hati aplikasi penipuan sertifikat  minggu udah  kluar  aplikasi   buka'
#  'aplikasi memudahkan untuk melakukan meeting online dimanapun  kapanpun fitur sangat lengkap'
#  'sangat membantu  kondisi  sekarang'
#  'conference call video chat share screen mudah gratis  kalau    harga  terjangkau  bayar transfer join room  lihat event  available bagus banget apps'
#  'bermanfaat apps tellhealth terima kasih tampil'
#  'keren sekali aplikasinya  pakai rapat lambat  batas  pakai      stop'
#  'aplikasinya sangat bagus cocok  dipakai meeting online  tunggu versi selanjutnya'
#  'mantap tampil menjadi solusi kami mahasiswa  sedang melaksanakan perkuliahan terima kasih'
#  'tampilan simpel fiturnya lengkap terutama share screen  dipakai buat belajar meeting  keperluan'
#  'aplikasinya sangat membantu meetingkuliah online  tampilannya sangat mudah dipahami tingkatkan'
#  'banget buat dipakai meeting online untuk video call group fiturnya lengkap simple  mudah digunakan'
#  'aplikasi  sangat bagus bantu dalam meeting online fiturnya sangat lengkap  mudah dioperasikan recommended banget buat kalian kalau urusan harga'
#  'aplikasi bagus desainnya simpel mudah digunakan  fiturnya menarik sangat ditunggu update selanjutnya'
#  'keren fiturnya lengkap  mudah digunakan cocok buat meeting online banyak peserta'
#  'cocok banget  buat meeting online fiturnya lengkap  mudah digunakan'
#  'bagus' 'cool apps'
#  'tampilan bagus  mudah dipahami fitur lengkap sangat direkomendasikan digunakan diera pandemi sekarang aplikasi sangat user friendly'
#  'membantu sekali kegiatan memerlukan tatap muka jarak jauh' 'bagus'
#  'tampilan aplikasi user friendly paket terjangkau sangat berguna  seperto sekarang'
#  'aksesnya sangat mudah' 'bagus' 'bagus' 'nice' 'bagus'
#  'sangat berguna sekali  video conference ataupun silaturahmi teman teman online'
#  'bagus' '' 'love this' 'keren' 'bagus'
#  'pake akun dulu padahal   meeting  harus itupun proses pendaftaran akunnya  sudah berkali kali  email   email verifikasi  dicoba login gabisa'
#  'bagus' 'bagus' 'mantap' 'bisa full screen    cuma hpku' 'great useful'
#  'bagus' 'bagus' 'fitur kurang  integrasi kalender'
#  'error pengambilan gambar upload foto profil' 'amazing'
#  'kasih bintang segini dulu   ditemukan daftar   menambahkan photo profil aplikasi sering force close proses pendaftaran bisa dilakukan kayak percuma install appsnya kalo gabisa terpakai gabisa upload profile mohon diperbaiki'
#  'bagus' 'bagus' 'manteps' 'sangatlah mantab'
#  'forced stop terus sejak update' 'bagus' 'bagus'
#  'perangkat   suaranya  download sertifikat   lapor problem ternyata    menu aplikasi jadinya lapor sini'
#  'bagus' '' 'bagus' 'mantul' 'bagus'
#  'tampil merupakan salah satu video conference terbilang bagus  bersaing aplikasi sejenis lainnya  jelas tampil  aplikasi video conference asli indonesia dibuat bisa  sebagai platform video conference tampil menyediakan berbagai event webinar dapat meningkatkan skill  sudah mendapatkan certificate pokoknya tampil mantap  sangat membanggakan negara indonesia'
#  'aplikasinya sangat berguna menambah ilmu  topik webinarnya sangat menarik terima kasih'
#  'aplikasi bagus mendapatkan ilmu workshop  webinar webinar isinya daging banget huhu'
#  'sesuai namanya aplikasi tampil menampilkan segala bentuk  webinar hingga event sangat bermanfaat menambah wawasan materi melalui online   merchandise bisa didapatkan teman teman download aplikasi tampil'
#  'aplikasinya bagus terutama buat pencari event penyelenggara event dapat digunakan konferensi event ataupun webinar dilengkapi share screen polling  tentunya acara busa mendownload sertifikat acaranya'
#  'aplikasi tampil  sangat mudah digunakan pemula  cocok sekali orang nyaman  belajar artificial intelligence melalu event webinar satu aplikasi sudah mendapatkan info lengkap mengenai event webinar terpusat banget sumbernya  sertifikatnya pokoknya keren'
#  'aplikasi bermanfaat terutama buat pencari event ataupun penyelenggara event'
#  'flatfoam   mantap awet kuota  mudah diaplikasikan' 'bagus' 'bagus'
#  'bagus'
#  'aplikasinya tambah  update  tambah lemot   ikut seminar jaringannya langsung down'
#  'webinarnyaa seru' 'bagus' 'bagus' 'bagus'
#  'pakai android  tidak  buka  klik aplikasi lgsg close'
#  'aplikasi bisa terbuka  android' 'bagus' '' ' buka   langsung keluar'
#  'sertifikatnya terlalu lama udah seminggu ikut event sertifikatnya turun turun'
#  'bagus' 'kerennn' 'application  open'
#  'very useful  easy   conference apps hope there having   great feature nextime '
#  'love' 'keren banget' 'baguss   date banget'
#  'aplikasinya keren  sangat bermanfaat'
#  'local masterpiece   find great speakers  learn about  from them'
#  'keren banget aplikasinya'
#  'diinstall aplikasi  error setelah  berjalan baik'
#  'such  helpful  useful' 'keren semoga semakin baik'
#  'aplikasi keren banget  berguna banget diera pandemi gini   dicari  recommended'
#  'semangat terus mengembangkan produk lokal bangga'
#  'aplikasinya bagus sangat informatif disaat pandemi gini semua serba online aplikasi  sangat recomended banget'
#  'very useful  such  great   learning' 'menarik  bagus'
#  'aplikasi cukup ngebantu kita butuh ikut kegiatan webinar informasi  disediakan sangat lengkap  memudahkan'
#  'very easy    useful' 'aplikasi sangat berguna mencari webinar terkait'
#  'useful'
#  'aplikasinya bagus sekali memuat beragam info webinar kita mengikuti webinar  tengah pandemi  sangar recomend sekali orang orang aktif  mencari banyak ilmu'
#  'aplikasinya bagus layanan disediakan bermanfaat  menarik banget'
#  'aplikasi bisa dipakai force closed dibuka' '' 'very usefull this apps'
#  'aplikasi sangat membantu kita  tetap produktif  masa oandemi  tampil memiliki banyak keunggulan webinad gratis hari sertifikat digital  diskusi langsung dengab narasumber sangat direkomendasikan aplikasi tampil '
#  'sangat membantu platform komunikasi digital tatap muka '
#  'sangat baik  semoga bersaing  dikenal masyarakat luas'
#  'terima kasih jadi aplikasi webinar  pembelajaran keren banyak belajar'
#  'salah satu platform lokal video conference semoga semakin menjadi terbaik kedepannya'
#  'bagus banget membantu buat cari webinar gratis'
#  'event webinar disediakan sangat menarik diikuti semoga performa tampil kedepannya semakin baik'
#  'keren sihh belajar melalui webinar  cocok  buat     pematerinya hebatt dibidangnya'
#  'sangat membantu produktif  kondisi pandemi'
#  'aplikasinya bagus sangat cocok digunakan dimasa pandemi   sangat membantu  mudah mengaplikasikan'
#  'tampil sangat baik menyelenggarakan eventevent sulit dicari terutama masa pandemi  webinarwebinar diadakan sangat bermanfaat  memberikan banyak benefit mereka mengikutinya sertifikat  hadiah'
#  'keren' 'sangat bermanfaat'
#  'bagus banget aplikasinya kalo webinar bener bener sangat mendukung  tampil'
#  'great'
#  'everytime  open this   always forces stop automatically  dunno    seeing   summary  think this  really useful  making  event webinar'
#  'mantap' 'aplikasi dapat menambah pengalaman' 'bagus' 'bagus'
#  'fullscreen  ' 'bagus'
#  'hadir event awal hingga akhir tidak  sertifikatnya tercatat saya melalui link lebih bagus linknya aplikasinya'
#  'koneksi lambat server lambat tampilan  video conference mirip sama udah  vendor  orang  bagian     repot ubah'
#  'gaada suara    diklik join audio  gaada'
#  'tampilan  sangat baik  kekinian akses aplikasi cukup ringan  sangat baik terus pertahankan semoga  kedepan semakin maju  sukses  terus  menyebar ilmu bermanfaat dibidang  buat masyarakat luas terima kasih'
#  'platform video conference bagus  banyak event event menarik data science   event menarik lainnya rugi install aplikasi  sangat bermanfaat good '
#  'bagus' 'bagus' 'bagus' 'udah ikut seminar  sertifikat  kaga' 'bagus'
#  'bagus' 'mantulpis ' 'bagus' 'diupdate malah keluar trus' 'well'
#  'semoga sertifikat gratis '
#  'bagusan    sertifikat  lama   percepat sebaiknya  hari' 'bagus' 'bagus'
#  'bagus' 'bagus' 'bagus' 'bagus' 'tipu² sertifikat   muncul² udah bayar'
#  'bagus' 'really helpfull' 'bagus' 'useful' '' 'bagus' 'bagus' 'bagus'
#  'aplikasi berfungsi baik'
#  'sedih banget baru update udah   buka force closed terus   team  mban atuh  ikutan belajar  enroll'
#  'mantap' 'sangat ringan' 'best meeting video conference appreciate that'
#  ' instal udah masukin email  password  kbuka² malah lagi udah gitu      sertifikat langsung konfirmasi dulu  alamat emailnya'
#  'bagus' 'produk asli lokal full support' 'bagus' 'bagus' 'bagus'
#  'stay logged  multiple wrong emailpassword warning even though    correct login info saved events disappearing from  event page  delete  account'
#  'mantap' 'mantap'
#  'aplikasinya  akhir segmen suka error kalo udah keluar  masuk webinarnya  sertifikat   padahal udah berhari webinar selesai appnya tiba   sendiri terus password dianggap salah terus padahal  benar coba klik reset password katanya konfirmasinya dikirim  email  udah lewat sehari   email masuk  aplikasi tampil   buat akun baru  email baru  hubungi kalian sesuai ketentuan  whatsapp    respon'
#  'aplikasinya bagus sedikit tambahan  masukkan penggunaan keyboard public chat seringkali gagal berfungsi kita sering terganggu akan menuliskan pertanyaan jawaban  masukan  penggunaan keyboard public chat sebaiknya preview textnya diperlihatkan diatas kelihatan  ngetik text preview tertutup keyboard terimakasih'
#  'bagus'
#  'bisa dibuka sama sekali selalu berhenti dibuka pernah berhasil membuka aplikasi'
#  'bagus' 'bagus'
#  'aplikasi tampil bisa lebih update informasi webinar bermanfaat menambah pengetahuan  mengembangkan skill'
#  'sangat baik sekali webinar'
#  'aplikasi  sangat membantu mahasiswa sedang mencari webinar daring pandemi webinar tersebut dibuat timeline tanggal  agustus hingga beberapa event lainnya  jangan takut mencoba'
#  'suka sama aplikasi  tinggal  tingkatkan'
#  '   zoom webinar gratis buat nambah wawasan support produk lokal'
#  'tenkyuu banget  kegiatan  ppkm  gini'
#  'sangat membantu dalam menemukan webinar nantinya bermanfaat memperkaya pengetahuan'
#  'bagus banget apknya dapet informsi webinar banyak' 'bagus'
#  'aplikasi  sangat bermanfaat berisi eventevent menarik belajar   event gratisnya sangat worth'
#  'aplikasi tampil  sangat bermanfaat memudahkan dalam mencari  mendaftar webinar event setiap harinya  juga diskusi langsung narasumber tentunya mendapatkan sertifikat apabila mengikuti eventwebinar aplikasi tampil aplikasi  dilengkapi layanan forum  berita banyak  benefit  didapatkan'
#  'aplikasi rekomended  dicoba meeting apapun terimakasih membuat pilihan aplikasi tidak jenuh'
#  'apliksi tampil menampilkan menyelenggarakan event webinar  pembelajaran menggunakan video conference dapat digunakan melalui  android   tampil membuka kesempatan untuk tampil  berkolaborasi dapat bergabung  room telah  informasikan tampil mempunyai parter rutin saya aplikasi  sangat membantu  masa pandemi'
#  'appnya useful  bagus '
#  'aplikasi  tiba susah dibuka  diperbaiki terimakasih'
#  'aplikasi  menyediakan info lengkaprksiy webinar  event terutama relate   tech bener bener rekomended  hrus  donlot'
#  'keren'
#  'aplikasi  sangat membantu dalam mengetahui kegiatan diluar seminar hanya  aplikasi  bisa ikut seminar  kegiatan lainnya'
#  'kerenn bangetttt aplikasi terbaik  playstore mantap'
#  'this  insighful aplication  looking  webinar  another activities that  create better education'
#  'very good apps  hold  educational webinar conference  workshop'
#  ' enthusiast  mahasiswa dimasa pandemi sekarang  sangat terbantu aplikasi  banyak workshop  event pelatihan² webinar rutin diadakan khusus terkait    teknologi lainnya dapet sertifikat fiturnya berupa video conference sangat efektif  mudah digunakan'
#  'aplikasinya bagusssdd'
#  'aplikasi tampil sangat berguna menampilkan menyelenggarakan event webinar  pembelajaran menggunakan video conference berbagai fitur ditampilkan membuat lebih mudah mengoperasikannya dapat bergabung  room telah diinformasikan tampil mempunyai parter rutin'
#  'aplikasi tampil  sangat membantu untuk mencari info webinar  mendaftar diaplikasi langsung  berhubungan langsung narasumber   lupa juga dapet sertifikat  '
#  'easy   great performance '
#  'sangat bermanfaat  memudahkan mahasiswa berkeinginan mengembangkan diri mengikuti berbagai conference'
#  'aplikasi  ringan penggunaan  fiturnya recomended banget' 'bagus'
#  'bermanfaat sekali pelajar umum cari event webinar   masa sekarang harus melalui virtual'
#  'aplikasi menyelenggarakan berbagai macam webinarevent bahkan conference mudah sekali  gunakan sangat rekomendasi buat temanteman mungkin sedang mencari webinar event menambah wawasan'
#  'sebagai mahasiswa aplikasi  bagus  sangat membantu menambah ilmu melalui webinar'
#  'aplikasi tampil mengadakan event webinar  diakses   android  sangat banyak benefit kita dari aplikasi'
#  'udah instal   dibuka  nyampe sedetik nutup sendiri huhuuu'
#  'informatif mantap sekali'
#  'aplikasi sangat bermanfaat  dalamnya memuat berbagai event mempermudah mahasiswa ingin mencari event webinar'
#  'aplikasi  bermanfaat kita  aktif webinar  mencari event dipermudah'
#  'this  suitable  whose seeking webinar  event this   useful' 'bagus'
#  'aplikasi inovatif semoga terus berkembang lebih baik  menjadi kontributor indonesia maju'
#  'aplikasinya aangat membantu mahasiswa mencari webinar'
#  'aplikasi sangat bermanfaat banyak informasi mengenai webinar maupun event gratis juga dapat sertifikat kalo ikutan webinarnya sangat membantu mengisi waktu luang dimasa pandemi'
#  'very useful'
#  'keren seruseru webinarnya ditunggu selalu webinar keren react  kemarin '
#  'aplikasinya sangat bermanfaat mencari webinar'
#  'mungkin  perluas fitur webinar aplikasinya biar mudah penggunaan'
#  'aplikasi  sangat berguna  bermanfaat membuat sebuah webinar aplikasi  banyak membantu berbagai kemudahan menyelenggarakan webinar'
#  'keren video conference ' 'webinar lancarr '
#  'aplikasi bagus  baru  platform aplikasi isinya webinar  sekaligus vidconf  aplikasi  kesannya sangat memuaskan '
#  'bagus' 'bagus'
#  'aplikasi karya anak bangsa  dibuat khusus webinar free  berbayar terhubung langsung  pemateri   dijadwalkan  aplikasi academy recommended  '
#  'aplikasi  bener  baru download masa  dibuka kluar sndiri bkin emosi   aplikasi'
#  'pengalaman menyenangkan'
#  'tampilan  pilihan webinarnya banyak keren banget' 'bagus' 'bagus'
#  'aplikasi berhenti sendiri akan daftar melalui gmail  sampai menit download aplikasi bisa dibuka'
#  'luar biasa' 'keren banget' 'bagus'
#  'keren banget aplikasi  ikut berbagai kegiatan  event' 'bagus'
#  'keren banget  aplikasi membantu banget buat pembelajaran online' 'bagus'
#  'mantap'
#  'menginspirasi tempat  belajar informatika keren banget mohon  pertahankan  mudahhan  tampil makin besar aminn'
#  'crash']

# %% [markdown]
# # Melihat grafik persebaran perkata & 2 kata

# %%
from sklearn.feature_extraction.text import CountVectorizer
def top_n_ngram(corpus,n = None,ngram = 1):
    vec = CountVectorizer(stop_words = 'english',ngram_range=(ngram,ngram)).fit(corpus)
    bag_of_words = vec.transform(corpus) #Have the count of  all the words for each review
    sum_words = bag_of_words.sum(axis =0) #Calculates the count of all the word in the whole review
    words_freq = [(word,sum_words[0,idx]) for word,idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq,key = lambda x:x[1],reverse = True)
    return words_freq[:n]

# %%
common_words = top_n_ngram(new_df['Review Text'], 20,1)
df = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
plt.figure(figsize =(10,5))
df.groupby('ReviewText').sum()['count'].sort_values(ascending=False).plot(
kind='bar', title='Top 20 unigrams in review after removing stop words')

# %%
common_words = top_n_ngram(new_df['Review Text'], 20,2)
df = pd.DataFrame(common_words, columns = ['ReviewText' , 'count'])
plt.figure(figsize =(10,5))
df.groupby('ReviewText').sum()['count'].sort_values(ascending=False).plot(
kind='bar', title='Top 20 bigrams in review after removing stop words')

# %%
#Lihat persebaran kata positif di review text nya setelah di pre process
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Positif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Lihat persebaran kata netral di review text nya setelah di pre process
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Netral')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Lihat persebaran kata negatif di review text nya setelah di pre process
from wordcloud import WordCloud, ImageColorGenerator
text = " ".join(str(review) for review in new_df[new_df['Sentiment'].str.contains('Negatif')]['Review Text'].dropna().unique() if len(review)>3) 
wordcloud = WordCloud(max_words=50,colormap='Set2', background_color="white").generate(text) 
plt.figure(figsize=(15,10)) 
plt.imshow(wordcloud) 
plt.show()

# %%
#Pelabelan kolom Sentiment
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
new_df['Sentiment'] = labelencoder.fit_transform(new_df['Sentiment'])

# %%
new_df
# Out:
#    Star Rating                                        Review Text  Sentiment
# 0            1                  payah seharian   buka aplikasinya          0
# 1            1  hati hati aplikasi penipuan sertifikat  minggu...          0
# 0            5  aplikasi memudahkan untuk melakukan meeting on...          2
# 1            5                 sangat membantu  kondisi  sekarang          2
# 2            5  conference call video chat share screen mudah ...          2
# ..         ...                                                ...        ...
# 4            5  keren banget  aplikasi membantu banget buat pe...          2
# 5            5                                              bagus          2
# 6            5                                             mantap          2
# 7            5  menginspirasi tempat  belajar informatika kere...          2
# 8            1                                              crash          0
#
# [250 rows x 3 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Star Rating  250 non-null    object
#  1   Review Text  250 non-null    object
#  2   Sentiment    250 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 7.8+ KB

# %%
new_df.describe()
# Out:
#         Sentiment
# count  250.000000
# mean     1.720000
# std      0.677818
# min      0.000000
# 25%      2.000000
# 50%      2.000000
# 75%      2.000000
# max      2.000000

# %%
y = new_df['Sentiment']
X = new_df["Review Text"]
print(y.value_counts())
# Out:
# 2    212
# 0     32
# 1      6
# Name: Sentiment, dtype: int64

# %%
#Tokenisasi
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
Xnew = tokenizer.texts_to_sequences(X)

# %%
Xnew
# Out:
# [[249, 250, 55, 8],
#  [134, 134, 2, 251, 14, 252, 18, 135, 2, 55],
#  [2, 70, 71, 253, 24, 19, 254, 255, 56, 3, 29],
#  [3, 11, 136, 57],
#  [12,
#   137,
#   15,
#   88,
#   89,
#   72,
#   13,
#   43,
#   138,
#   139,
#   140,
#   141,
#   256,
#   142,
#   90,
#   257,
#   5,
#   258,
#   1,
#   7,
#   44],
#  [10, 44, 259, 58, 45, 6],
#  [9, 20, 8, 91, 260, 92, 261, 91, 93],
#  [8, 3, 1, 46, 73, 24, 19, 262, 263, 143],
#  [21, 6, 94, 264, 265, 34, 95, 266, 267, 58, 45],
#  [47, 144, 30, 29, 59, 89, 72, 73, 16, 35, 24, 268],
#  [8, 3, 11, 269, 19, 270, 3, 13, 145, 146],
#  [7, 16, 73, 24, 19, 71, 15, 137, 271, 30, 29, 272, 13, 25],
#  [2, 3, 1, 273, 74, 24, 19, 30, 3, 29, 13, 274, 96, 7, 16, 147, 138, 275, 139],
#  [2, 1, 276, 144, 13, 25, 30, 31, 3, 148, 60, 143],
#  [9, 30, 29, 13, 25, 46, 16, 24, 19, 17, 277],
#  [46, 7, 16, 24, 19, 30, 29, 13, 25],
#  [1],
#  [278, 44],
#  [47, 1, 13, 145, 56, 29, 3, 149, 25, 150, 22, 57, 2, 3, 151, 152],
#  [11, 20, 48, 279, 153, 154, 280, 281],
#  [1],
#  [47, 2, 151, 152, 282, 140, 3, 36, 283, 57],
#  [284, 3, 13],
#  [1],
#  [1],
#  [285],
#  [1],
#  [3, 36, 20, 15, 12, 97, 286, 75, 75, 19],
#  [1],
#  [],
#  [155, 37],
#  [9],
#  [1],
#  [287,
#   156,
#   98,
#   99,
#   24,
#   157,
#   288,
#   158,
#   159,
#   289,
#   100,
#   290,
#   291,
#   49,
#   49,
#   292,
#   160,
#   161,
#   101],
#  [1],
#  [1],
#  [21],
#  [26, 162, 72, 293, 294],
#  [50, 23],
#  [1],
#  [1],
#  [56, 295, 296, 297],
#  [102, 298, 299, 163, 300, 164],
#  [301],
#  [45,
#   302,
#   303,
#   98,
#   304,
#   165,
#   305,
#   306,
#   164,
#   2,
#   166,
#   103,
#   167,
#   158,
#   159,
#   26,
#   307,
#   308,
#   309,
#   168,
#   310,
#   76,
#   101,
#   311,
#   101,
#   163,
#   312,
#   169,
#   170],
#  [1],
#  [1],
#  [313],
#  [314, 315],
#  [316, 93, 32, 317, 60],
#  [1],
#  [1],
#  [318, 319, 77, 14, 171, 320, 321, 322, 2, 323, 171, 324],
#  [1],
#  [],
#  [1],
#  [325],
#  [1],
#  [6,
#   326,
#   104,
#   105,
#   15,
#   12,
#   327,
#   1,
#   172,
#   2,
#   328,
#   61,
#   329,
#   6,
#   2,
#   15,
#   12,
#   173,
#   106,
#   107,
#   26,
#   174,
#   62,
#   15,
#   12,
#   6,
#   175,
#   38,
#   5,
#   4,
#   39,
#   330,
#   176,
#   100,
#   78,
#   331,
#   177,
#   6,
#   21,
#   3,
#   332,
#   333,
#   106],
#  [8, 3, 36, 51, 63, 334, 64, 3, 31, 58, 45],
#  [2, 1, 78, 63, 108, 4, 4, 178, 335, 7, 336],
#  [179,
#   337,
#   2,
#   6,
#   109,
#   338,
#   339,
#   4,
#   110,
#   5,
#   3,
#   10,
#   51,
#   111,
#   340,
#   40,
#   19,
#   341,
#   26,
#   180,
#   75,
#   75,
#   77,
#   2,
#   6],
#  [8,
#   1,
#   59,
#   16,
#   181,
#   5,
#   182,
#   5,
#   39,
#   25,
#   342,
#   5,
#   97,
#   4,
#   183,
#   89,
#   72,
#   343,
#   184,
#   344,
#   345,
#   346,
#   14,
#   347],
#  [2,
#   6,
#   3,
#   13,
#   25,
#   348,
#   46,
#   20,
#   79,
#   349,
#   35,
#   350,
#   351,
#   352,
#   5,
#   4,
#   105,
#   2,
#   100,
#   78,
#   65,
#   29,
#   185,
#   5,
#   4,
#   353,
#   7,
#   354,
#   80,
#   177,
#   9],
#  [2, 10, 59, 16, 181, 5, 97, 182, 5],
#  [355, 21, 356, 357, 13, 358],
#  [1],
#  [1],
#  [1],
#  [8, 186, 60, 186, 359, 52, 81, 360, 33, 361],
#  [362, 363],
#  [1],
#  [1],
#  [1],
#  [91, 82, 112, 55, 187, 2, 364, 167],
#  [2, 26, 365, 82],
#  [1],
#  [],
#  [55, 33, 113],
#  [80, 366, 188, 18, 367, 52, 5, 80, 189, 189],
#  [1],
#  [368],
#  [369, 190],
#  [53, 23, 114, 12, 44, 370, 371, 372, 50, 373, 374],
#  [155],
#  [9, 7],
#  [375, 376, 7],
#  [8, 9, 3, 10],
#  [377, 378, 379, 50, 380, 381, 382, 191, 383],
#  [9, 7, 8],
#  [384, 2, 102, 385, 386, 27],
#  [192, 387, 23],
#  [9, 41, 83, 27],
#  [2, 9, 7, 36, 7, 150, 22, 115, 193, 96],
#  [388, 32, 116, 117, 84, 389],
#  [8, 1, 3, 194, 390, 22, 115, 391, 392, 19, 2, 3, 195, 7],
#  [53, 23, 192, 50, 393],
#  [31, 1],
#  [2, 196, 394, 54, 395, 52, 48, 4, 118, 119, 3, 29, 70],
#  [53, 114, 23],
#  [2, 3, 36, 28, 4, 197],
#  [23],
#  [8,
#   1,
#   20,
#   198,
#   396,
#   65,
#   4,
#   54,
#   120,
#   4,
#   397,
#   22,
#   398,
#   399,
#   20,
#   79,
#   79,
#   199,
#   28,
#   17,
#   63],
#  [8, 1, 200, 119, 10, 31, 7],
#  [2, 26, 73, 103, 201, 42],
#  [],
#  [53, 400, 37, 44],
#  [2,
#   3,
#   11,
#   54,
#   401,
#   202,
#   66,
#   402,
#   6,
#   403,
#   17,
#   404,
#   405,
#   43,
#   203,
#   14,
#   204,
#   205,
#   33,
#   406,
#   121,
#   3,
#   149,
#   2,
#   6],
#  [3, 11, 62, 407, 204, 153, 154],
#  [3, 27, 41, 172, 408, 206, 207],
#  [58, 45, 409, 2, 4, 85, 9, 17, 35],
#  [104, 105, 62, 84, 15, 12, 41, 83, 94, 208, 209],
#  [1, 7, 11, 16, 210, 4, 43],
#  [5, 4, 119, 3, 31, 410, 41, 411, 6, 209, 83, 27],
#  [9, 412, 35, 40, 4, 46, 16, 413, 414, 415],
#  [3, 11, 202, 136, 22],
#  [8, 1, 3, 46, 25, 122, 22, 3, 11, 13, 416],
#  [6,
#   3,
#   27,
#   67,
#   211,
#   417,
#   193,
#   59,
#   66,
#   22,
#   418,
#   212,
#   3,
#   10,
#   419,
#   17,
#   123,
#   420,
#   421,
#   14,
#   422],
#  [9],
#  [3, 10],
#  [1, 7, 8, 76, 4, 68, 68, 3, 423, 6],
#  [50],
#  [424, 190, 37, 425, 426, 93, 427, 428, 429, 430, 431, 37, 213, 23, 432, 5, 4],
#  [21],
#  [2, 39, 51, 214],
#  [1],
#  [1],
#  [433],
#  [1],
#  [434, 5, 435, 110, 215, 112, 80, 436, 216, 40, 437, 86, 1, 438, 8],
#  [439, 92, 440, 92, 47, 15, 12, 441, 124, 18, 442, 79, 443, 444, 445],
#  [217, 446, 447, 142, 448, 217],
#  [47,
#   3,
#   27,
#   449,
#   450,
#   2,
#   196,
#   125,
#   3,
#   27,
#   32,
#   218,
#   41,
#   451,
#   83,
#   219,
#   452,
#   32,
#   453,
#   63,
#   10,
#   454,
#   16,
#   206,
#   207,
#   58,
#   45],
#  [62, 15, 12, 1, 17, 5, 5, 31, 455, 456, 5, 31, 61, 457, 168, 2, 3, 10, 220],
#  [1],
#  [1],
#  [1],
#  [18, 52, 81, 14, 458],
#  [1],
#  [1],
#  [459],
#  [1],
#  [460, 221, 113, 461],
#  [462],
#  [41, 14, 43],
#  [463, 14, 188, 464, 222, 203],
#  [1],
#  [1],
#  [1],
#  [1],
#  [1],
#  [1],
#  [465, 14, 466, 18, 141],
#  [1],
#  [213, 467],
#  [1],
#  [23],
#  [],
#  [1],
#  [1],
#  [1],
#  [2, 223, 27],
#  [468, 7, 69, 60, 18, 55, 103, 201, 32, 469, 470, 471, 224, 35, 472],
#  [21],
#  [3, 125],
#  [473, 24, 15, 12, 474, 225],
#  [226, 18, 475, 49, 126, 476, 221, 477, 18, 478, 14, 33, 479, 98, 480, 481],
#  [1],
#  [117, 173, 84, 162, 227],
#  [1],
#  [1],
#  [1],
#  [482,
#   483,
#   484,
#   485,
#   486,
#   487,
#   488,
#   489,
#   490,
#   161,
#   65,
#   491,
#   492,
#   493,
#   191,
#   5,
#   494,
#   495,
#   496],
#  [21],
#  [21],
#  [8,
#   215,
#   497,
#   228,
#   102,
#   76,
#   18,
#   113,
#   229,
#   64,
#   14,
#   99,
#   18,
#   498,
#   4,
#   499,
#   230,
#   231,
#   127,
#   32,
#   126,
#   500,
#   104,
#   32,
#   99,
#   501,
#   502,
#   187,
#   503,
#   126,
#   504,
#   505,
#   506,
#   49,
#   18,
#   507,
#   508,
#   49,
#   229,
#   2,
#   6,
#   16,
#   156,
#   69,
#   49,
#   69,
#   509,
#   147,
#   179,
#   510,
#   511,
#   512],
#  [8,
#   1,
#   513,
#   514,
#   515,
#   87,
#   128,
#   232,
#   88,
#   516,
#   517,
#   223,
#   54,
#   166,
#   518,
#   233,
#   519,
#   520,
#   521,
#   522,
#   87,
#   128,
#   232,
#   88,
#   222,
#   234,
#   523,
#   524,
#   525,
#   526,
#   527,
#   528,
#   234,
#   529,
#   128,
#   129],
#  [1],
#  [26, 42, 124, 20, 235, 236, 42, 530, 531, 237, 2],
#  [1],
#  [1],
#  [2, 6, 26, 86, 60, 118, 4, 10, 51, 238, 116, 176],
#  [3, 27, 20, 4],
#  [2,
#   3,
#   11,
#   34,
#   95,
#   28,
#   4,
#   532,
#   22,
#   4,
#   533,
#   107,
#   534,
#   535,
#   536,
#   110,
#   537,
#   5,
#   61,
#   538,
#   539,
#   540],
#  [228, 124, 2, 541, 146],
#  [542, 4, 43, 16, 543, 111, 227, 117, 84],
#  [544, 7, 48, 545, 115],
#  [3, 11, 74, 546, 4, 547, 10, 548, 238],
#  [1, 7, 549, 130, 550, 4, 17],
#  [1],
#  [2, 3, 10, 551, 211, 31, 35, 5, 552, 3, 553],
#  [2,
#   6,
#   3,
#   10,
#   70,
#   74,
#   28,
#   239,
#   4,
#   5,
#   554,
#   555,
#   131,
#   205,
#   33,
#   121,
#   184,
#   78,
#   14,
#   556,
#   120,
#   557,
#   2,
#   6,
#   2,
#   183,
#   200,
#   558,
#   559,
#   17,
#   123,
#   180],
#  [2, 240, 160, 24, 560, 129, 132, 241, 2, 112, 561],
#  [562,
#   6,
#   109,
#   67,
#   5,
#   4,
#   85,
#   242,
#   15,
#   12,
#   39,
#   25,
#   40,
#   82,
#   6,
#   237,
#   563,
#   71,
#   6,
#   564,
#   39,
#   243,
#   90,
#   244,
#   565,
#   6,
#   245,
#   246,
#   133,
#   216,
#   2,
#   3,
#   11,
#   66,
#   22],
#  [230, 23, 1],
#  [2, 231, 566, 42, 170, 129],
#  [2, 175, 65, 567, 4, 5, 59, 568, 569, 68, 68, 240, 570, 571],
#  [9],
#  [2, 3, 11, 74, 572, 48, 573, 81, 574, 2, 26, 52, 81, 48, 61],
#  [575, 576, 2, 208, 577, 21],
#  [37, 578, 579, 580, 4, 581, 582, 225, 583, 584, 585],
#  [53, 220, 44, 586, 587, 4, 12, 108],
#  [588,
#   34,
#   122,
#   22,
#   57,
#   3,
#   589,
#   2,
#   17,
#   108,
#   5,
#   590,
#   4,
#   133,
#   212,
#   247,
#   197,
#   591,
#   61,
#   130,
#   14,
#   30,
#   592,
#   15,
#   12,
#   3,
#   593,
#   13,
#   25],
#  [8, 594],
#  [2,
#   6,
#   3,
#   36,
#   109,
#   67,
#   5,
#   4,
#   85,
#   242,
#   15,
#   12,
#   38,
#   56,
#   595,
#   132,
#   86,
#   13,
#   596,
#   39,
#   243,
#   90,
#   244,
#   597,
#   6,
#   245,
#   246,
#   133],
#  [2, 6, 3, 11, 71, 28, 65, 4, 239, 598, 33, 599, 33, 121, 600, 131, 130, 14],
#  [114, 50, 601],
#  [3, 10, 70, 34, 602, 116, 603, 120, 38, 12],
#  [2, 125, 87, 30, 195, 7],
#  [1],
#  [10, 20, 604, 605, 210, 5, 4, 66, 57, 157, 40, 606],
#  [2,
#   67,
#   38,
#   607,
#   608,
#   609,
#   12,
#   13,
#   20,
#   610,
#   3,
#   611,
#   16,
#   612,
#   248,
#   95,
#   28,
#   4,
#   5,
#   51,
#   111],
#  [174, 34, 2, 1, 3, 11, 51, 63, 40, 4],
#  [2, 6, 613, 5, 4, 614, 82, 3, 17, 123, 54, 615, 2],
#  [18, 226, 42, 616, 617, 618, 127, 619],
#  [194, 21, 20],
#  [2, 3, 10, 620, 198, 38, 5, 621, 34, 622, 28, 5, 4],
#  [2, 10, 54, 199, 4, 28, 5, 623],
#  [37, 624, 625, 626, 4, 5, 37, 23],
#  [1],
#  [2, 627, 41, 32, 628, 86, 27, 94, 629, 106, 219],
#  [8, 630, 11, 34, 28, 4],
#  [2,
#   3,
#   10,
#   17,
#   118,
#   185,
#   4,
#   631,
#   5,
#   43,
#   131,
#   39,
#   14,
#   76,
#   224,
#   64,
#   3,
#   11,
#   632,
#   633,
#   634,
#   122,
#   22],
#  [53, 23],
#  [9, 635, 64, 148, 235, 4, 9, 636, 637],
#  [8, 3, 10, 28, 4],
#  [248, 638, 56, 4, 8, 639, 13, 87],
#  [2, 3, 36, 10, 132, 640, 4, 2, 17, 11, 38, 641, 67, 4],
#  [9, 15, 12],
#  [4, 642],
#  [2, 1, 69, 62, 2, 178, 4, 643, 644, 2, 645, 3, 646],
#  [1],
#  [1],
#  [2, 647, 648, 649, 107, 247, 4, 650, 651, 652, 33, 653, 654, 2, 655, 96],
#  [2, 68, 69, 77, 66, 42, 135, 656, 657, 658, 2],
#  [214, 659],
#  [47, 241, 64, 17, 9, 7],
#  [1],
#  [1],
#  [2, 236, 127, 233, 165, 40, 660, 661, 662, 77, 2, 26, 42],
#  [663, 664],
#  [9, 7],
#  [1],
#  [9, 7, 2, 52, 38, 48, 5],
#  [1],
#  [9, 7, 2, 11, 7, 16, 85, 19],
#  [1],
#  [21],
#  [665, 666, 35, 667, 9, 7, 169, 218, 668, 6, 669, 670, 671],
#  [672]]

# %%
vocab_size = len(tokenizer.word_index)+1
vocab_size
# Out:
# 673

# %%
Xbaru = pad_sequences(Xnew, padding = "post")

# %%
Xbaru
# Out:
# array([[249, 250,  55, ...,   0,   0,   0],
#        [134, 134,   2, ...,   0,   0,   0],
#        [  2,  70,  71, ...,   0,   0,   0],
#        ...,
#        [ 21,   0,   0, ...,   0,   0,   0],
#        [665, 666,  35, ...,   0,   0,   0],
#        [672,   0,   0, ...,   0,   0,   0]], dtype=int32)

# %%
y
# Out:
# 0    0
# 1    0
# 0    2
# 1    2
# 2    2
#     ..
# 4    2
# 5    2
# 6    2
# 7    2
# 8    0
# Name: Sentiment, Length: 250, dtype: int64

# %%
#Imbalance data
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(Xbaru, y, test_size=0.2, random_state=0)

print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions X_train dataset:  (200, 52)
# Number transactions y_train dataset:  (200,)
# Number transactions X_test dataset:  (50, 52)
# Number transactions y_test dataset:  (50,)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))
print("Before OverSampling, counts of label '2': {} \n".format(sum(y_train==2)))

sm = SMOTE(random_state=2, k_neighbors=3)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
print("Before OverSampling, counts of label '2': {} \n".format(sum(y_train==2)))
# Out:
# Before OverSampling, counts of label '1': 5
# Before OverSampling, counts of label '0': 26
#
# Before OverSampling, counts of label '2': 169
#
# After OverSampling, the shape of train_X: (507, 52)
# After OverSampling, the shape of train_y: (507,)
#
# After OverSampling, counts of label '1': 169
# After OverSampling, counts of label '0': 169
# Before OverSampling, counts of label '2': 169

# %% [markdown]
# # Permodelan dengan LSTM

# %%
# Pembuatan Model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense , Input , LSTM , Embedding, Dropout , Activation, GRU, Flatten
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model, Sequential
from keras.layers import Convolution1D
from keras import initializers, regularizers, constraints, optimizers, layers
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import keras

# %%
embedding_dim = 64
units = 256

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length = Xbaru.shape[1]))
model.add(LSTM(units))
model.add(Dense(512, activation="sigmoid"))
model.add(Dense(3, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 52, 64)            43072
#
#  lstm (LSTM)                 (None, 256)               328704
#
#  dense (Dense)               (None, 512)               131584
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 504,899
# Trainable params: 504,899
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics = ['accuracy'])

# %%
#Train Model
history = model.fit(X_train,y_train, epochs=30, batch_size=64, validation_split=0.2,verbose=1,shuffle=True)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 4s 524ms/step - loss: 1.3867 - accuracy: 0.2000 - val_loss: 0.7802 - val_accuracy: 0.8250
# Epoch 2/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.7018 - accuracy: 0.8500 - val_loss: 0.5934 - val_accuracy: 0.8250
# Epoch 3/30
# 3/3 [==============================] - 1s 264ms/step - loss: 0.5281 - accuracy: 0.8500 - val_loss: 0.5836 - val_accuracy: 0.8250
# Epoch 4/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.5226 - accuracy: 0.8500 - val_loss: 0.5889 - val_accuracy: 0.8250
# Epoch 5/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.5201 - accuracy: 0.8500 - val_loss: 0.5779 - val_accuracy: 0.8250
# Epoch 6/30
# 3/3 [==============================] - 1s 255ms/step - loss: 0.5103 - accuracy: 0.8500 - val_loss: 0.5589 - val_accuracy: 0.8250
# Epoch 7/30
# 3/3 [==============================] - 1s 263ms/step - loss: 0.4963 - accuracy: 0.8500 - val_loss: 0.5426 - val_accuracy: 0.8250
# Epoch 8/30
# 3/3 [==============================] - 1s 257ms/step - loss: 0.4952 - accuracy: 0.8500 - val_loss: 0.5399 - val_accuracy: 0.8250
# Epoch 9/30
# 3/3 [==============================] - 1s 254ms/step - loss: 0.4976 - accuracy: 0.8500 - val_loss: 0.5410 - val_accuracy: 0.8250
# Epoch 10/30
# 3/3 [==============================] - 1s 260ms/step - loss: 0.4991 - accuracy: 0.8500 - val_loss: 0.5404 - val_accuracy: 0.8250
# Epoch 11/30
# 3/3 [==============================] - 1s 267ms/step - loss: 0.4970 - accuracy: 0.8500 - val_loss: 0.5423 - val_accuracy: 0.8250
# Epoch 12/30
# 3/3 [==============================] - 1s 264ms/step - loss: 0.4953 - accuracy: 0.8500 - val_loss: 0.5475 - val_accuracy: 0.8250
# Epoch 13/30
# 3/3 [==============================] - 1s 267ms/step - loss: 0.4948 - accuracy: 0.8500 - val_loss: 0.5470 - val_accuracy: 0.8250
# Epoch 14/30
# 3/3 [==============================] - 1s 270ms/step - loss: 0.4940 - accuracy: 0.8500 - val_loss: 0.5453 - val_accuracy: 0.8250
# Epoch 15/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.4933 - accuracy: 0.8500 - val_loss: 0.5419 - val_accuracy: 0.8250
# Epoch 16/30
# 3/3 [==============================] - 1s 263ms/step - loss: 0.4908 - accuracy: 0.8500 - val_loss: 0.5389 - val_accuracy: 0.8250
# Epoch 17/30
# 3/3 [==============================] - 1s 257ms/step - loss: 0.4935 - accuracy: 0.8500 - val_loss: 0.5372 - val_accuracy: 0.8250
# Epoch 18/30
# 3/3 [==============================] - 1s 272ms/step - loss: 0.4923 - accuracy: 0.8500 - val_loss: 0.5379 - val_accuracy: 0.8250
# Epoch 19/30
# 3/3 [==============================] - 1s 261ms/step - loss: 0.4919 - accuracy: 0.8500 - val_loss: 0.5384 - val_accuracy: 0.8250
# Epoch 20/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.4919 - accuracy: 0.8500 - val_loss: 0.5383 - val_accuracy: 0.8250
# Epoch 21/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.4898 - accuracy: 0.8500 - val_loss: 0.5412 - val_accuracy: 0.8250
# Epoch 22/30
# 3/3 [==============================] - 1s 261ms/step - loss: 0.4908 - accuracy: 0.8500 - val_loss: 0.5447 - val_accuracy: 0.8250
# Epoch 23/30
# 3/3 [==============================] - 1s 267ms/step - loss: 0.4933 - accuracy: 0.8500 - val_loss: 0.5465 - val_accuracy: 0.8250
# Epoch 24/30
# 3/3 [==============================] - 1s 254ms/step - loss: 0.4926 - accuracy: 0.8500 - val_loss: 0.5416 - val_accuracy: 0.8250
# Epoch 25/30
# 3/3 [==============================] - 1s 259ms/step - loss: 0.4905 - accuracy: 0.8500 - val_loss: 0.5392 - val_accuracy: 0.8250
# Epoch 26/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.4908 - accuracy: 0.8500 - val_loss: 0.5376 - val_accuracy: 0.8250
# Epoch 27/30
# 3/3 [==============================] - 1s 273ms/step - loss: 0.4917 - accuracy: 0.8500 - val_loss: 0.5373 - val_accuracy: 0.8250
# Epoch 28/30
# 3/3 [==============================] - 1s 255ms/step - loss: 0.4917 - accuracy: 0.8500 - val_loss: 0.5385 - val_accuracy: 0.8250
# Epoch 29/30
# 3/3 [==============================] - 1s 254ms/step - loss: 0.4912 - accuracy: 0.8500 - val_loss: 0.5391 - val_accuracy: 0.8250
# Epoch 30/30
# 3/3 [==============================] - 1s 258ms/step - loss: 0.4928 - accuracy: 0.8500 - val_loss: 0.5378 - val_accuracy: 0.8250

# %%
#Menampilkan hasil training model ke dalam grafik
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'])
plt.show()

# %% [markdown]
# #Plot Model

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model)

# %% [markdown]
# #Evaluasi Model

# %%
predicted = model.predict(X_test)

# %%
predicted_class = np.argmax(predicted, axis=1)

# %%
predicted_class
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2])

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
cm = confusion_matrix(y_test, predicted_class)
sns.heatmap(cm, annot=True, cmap = 'coolwarm')

# %%
print(classification_report(y_test, predicted_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.00      0.00      0.00         1
#            2       0.86      1.00      0.92        43
#
#     accuracy                           0.86        50
#    macro avg       0.29      0.33      0.31        50
# weighted avg       0.74      0.86      0.80        50
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
